# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\USER\Desktop\5thsem_OJT\project1_diabeties\data\prosessed\fizan_P1W2_features.csv")

# %%
df["outcome"].value_counts(normalize=True)
# Out:
# outcome
# 0    0.712632
# 1    0.287368
# Name: proportion, dtype: float64

# %% [markdown]
# seperate the features from the target

# %%
feature_cols = ["age","pregnancies","glucose","blood_pressure","skin_thickness","insulin","bmi","diabetes_pedigree","bmi_catogory","glucose_band"]

x = df[feature_cols].copy()
y = df["outcome"]

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 945    0
# 946    1
# 947    0
# 948    0
# 949    0
# Name: outcome, Length: 950, dtype: int64

# %%
x
# Out:
#       age  pregnancies  glucose  blood_pressure  skin_thickness  insulin  \
# 0    79.0            0    124.0            71.0            30.0    124.0
# 1    37.0            0    153.0            85.0            24.0     42.0
# 2    39.0            0    142.0            68.0            22.0    159.0
# 3    68.0            7    121.0            88.0            26.0    124.0
# 4    75.0            0    107.0            84.0            31.0    101.0
# ..    ...          ...      ...             ...             ...      ...
# 945  64.0            2    117.0            81.0            34.0    124.0
# 946  71.0            0    140.0            64.0            37.0    124.0
# 947  40.0            0    130.0            73.0            26.0    258.0
# 948  52.0            4    123.0            76.0            22.0    189.0
# 949  42.0            0    114.0            73.0            34.0    124.0
#
#       bmi  diabetes_pedigree bmi_catogory  glucose_band
# 0    23.4              0.588       normal  pre_diebetic
# 1    33.9              0.192       obeese      diebetic
# 2    26.9              0.777   overweight      diebetic
# 3    29.0              1.217   overweight  pre_diebetic
# 4    21.2              0.278       normal  pre_diebetic
# ..    ...                ...          ...           ...
# 945  40.3              0.641       obeese  pre_diebetic
# 946  33.4              0.116       obeese      diebetic
# 947  20.1              0.709       normal      diebetic
# 948  38.9              0.540       obeese  pre_diebetic
# 949  28.2              0.819   overweight  pre_diebetic
#
# [950 rows x 10 columns]

# %% [markdown]
# encode your banded features

# %%
x = pd.get_dummies(x,drop_first=True)

# %%
x.shape
# Out:
# (950, 13)

# %%
x
# Out:
#       age  pregnancies  glucose  blood_pressure  skin_thickness  insulin  \
# 0    79.0            0    124.0            71.0            30.0    124.0
# 1    37.0            0    153.0            85.0            24.0     42.0
# 2    39.0            0    142.0            68.0            22.0    159.0
# 3    68.0            7    121.0            88.0            26.0    124.0
# 4    75.0            0    107.0            84.0            31.0    101.0
# ..    ...          ...      ...             ...             ...      ...
# 945  64.0            2    117.0            81.0            34.0    124.0
# 946  71.0            0    140.0            64.0            37.0    124.0
# 947  40.0            0    130.0            73.0            26.0    258.0
# 948  52.0            4    123.0            76.0            22.0    189.0
# 949  42.0            0    114.0            73.0            34.0    124.0
#
#       bmi  diabetes_pedigree  bmi_catogory_obeese  bmi_catogory_overweight  \
# 0    23.4              0.588                False                    False
# 1    33.9              0.192                 True                    False
# 2    26.9              0.777                False                     True
# 3    29.0              1.217                False                     True
# 4    21.2              0.278                False                    False
# ..    ...                ...                  ...                      ...
# 945  40.3              0.641                 True                    False
# 946  33.4              0.116                 True                    False
# 947  20.1              0.709                False                    False
# 948  38.9              0.540                 True                    False
# 949  28.2              0.819                False                     True
#
#      bmi_catogory_under_weight  glucose_band_diebetic  \
# 0                        False                  False
# 1                        False                   True
# 2                        False                   True
# 3                        False                  False
# 4                        False                  False
# ..                         ...                    ...
# 945                      False                  False
# 946                      False                   True
# 947                      False                   True
# 948                      False                  False
# 949                      False                  False
#
#      glucose_band_pre_diebetic
# 0                         True
# 1                        False
# 2                        False
# 3                         True
# 4                         True
# ..                         ...
# 945                       True
# 946                      False
# 947                      False
# 948                       True
# 949                       True
#
# [950 rows x 13 columns]

# %% [markdown]
# spIit into training and testing  sets

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(
    x,y, test_size=0.2, random_state=42, stratify=y
)

# %%
x_test.shape
# Out:
# (190, 13)

# %% [markdown]
# confirm the spIit behaved

# %%
x_train.shape
# Out:
# (760, 13)

# %%
print(y_train.value_counts(normalize=True))
print(y_test.value_counts(normalize=True))
# Out:
# outcome
# 0    0.713158
# 1    0.286842
# Name: proportion, dtype: float64
# outcome
# 0    0.710526
# 1    0.289474
# Name: proportion, dtype: float64
