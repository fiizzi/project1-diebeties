# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\USER\Desktop\5thsem_OJT\project1_diabeties\data\raw\project1_diabetes_raw.csv")

# %%
len("df")
# Out:
# 2

# %% [markdown]
# print onIy 100 rows

# %%
df_100=pd.read_csv(r"C:\Users\USER\Desktop\5thsem_OJT\project1_diabeties\data\raw\project1_diabetes_raw.csv",nrows=100)

# %%
df_100
# Out:
#    patient_id  age   gender  pregnancies  glucose  blood_pressure  \
# 0      P00826   79     male            0      124              71
# 1      P00108   37     Male            0      153              85
# 2      P00517   39        F            0      142              68
# 3      P00687   68   female            7      121              88
# 4      P00927   75   female            0      107              84
# ..        ...  ...      ...          ...      ...             ...
# 95     P00475   67     Male            0       76              77
# 96     P00615   77        F            7       76              72
# 97     P00155   43   female            3      115              62
# 98     P00260   44     Male            0      111              63
# 99     P00290   78  Female             0      129              79
#
#     skin_thickness  insulin   bmi  diabetes_pedigree physical_activity smoker  \
# 0               30        0  23.4              0.588               NaN     No
# ...

# %%
df.shape
# Out:
# (968, 14)

# %%
df.shape[0]
# Out:
# 968

# %%
df.shape[1]
# Out:
# 14

# %% [markdown]
# Iist every coIumn name

# %%
df.columns.tolist()
# Out:
# ['patient_id',
#  'age',
#  'gender',
#  'pregnancies',
#  'glucose',
#  'blood_pressure',
#  'skin_thickness',
#  'insulin',
#  'bmi',
#  'diabetes_pedigree',
#  'physical_activity',
#  'smoker',
#  'last_checkup_date',
#  'outcome']

# %% [markdown]
# Inspect the inferred types

# %%
df.dtypes
# Out:
# patient_id               str
# age                  float64
# gender                   str
# pregnancies            int64
# glucose                int64
# blood_pressure         int64
# skin_thickness         int64
# insulin                int64
# bmi                  float64
# diabetes_pedigree    float64
# physical_activity        str
# smoker                   str
# last_checkup_date        str
# outcome                int64
# dtype: object

# %% [markdown]
# finded top 10 rows

# %%
  df.head(10)
# Out:
#   patient_id   age  gender  pregnancies  glucose  blood_pressure  \
# 0     P00826  79.0    male            0      124              71
# 1     P00108  37.0    Male            0      153              85
# 2     P00517  39.0       F            0      142              68
# 3     P00687  68.0  female            7      121              88
# 4     P00927  75.0  female            0      107              84
# 5     P00755  37.0  female            0      145              80
# 6     P00431  58.0    Male            5       95              72
# 7     P00542  58.0  Female            3      150              68
# 8     P00929  32.0  Female            6      129              74
# 9     P00513  61.0  Female            0      161              77
#
#    skin_thickness  insulin   bmi  diabetes_pedigree physical_activity smoker  \
# 0              30        0  23.4              0.588               NaN     No
# 1              24       42  33.9              0.192           medium       Y
# ...

# %% [markdown]
# print bottom 10 roows

# %%
df.tail(10)
# Out:
#     patient_id   age  gender  pregnancies  glucose  blood_pressure  \
# 958     P00584  47.0  Female            0      107              59
# 959     P00674  42.0  Female            5      124              71
# 960     P00333  59.0    Male            0      141              67
# 961     P00270  36.0    Male            0       99              52
# 962     P00501  39.0    Male            0       92              62
# 963     P00338  64.0    male            2        0              81
# 964     P00092  71.0       F            0      140              64
# 965     P00081  40.0  Female            0      130              73
# 966     P00704  52.0       F            4      123              76
# 967     P00922  42.0    Male            0      114              73
#
#      skin_thickness  insulin   bmi  diabetes_pedigree physical_activity  \
# 958              26       98  32.7              0.050              HIGH
# 959              22      121   NaN              0.400               NaN
# ...

# %% [markdown]
# random 10 rows
#
# and fixed with random state

# %%
df.sample(10,random_state=1)
# Out:
#     patient_id   age  gender  pregnancies  glucose  blood_pressure  \
# 773     P00735  24.0  female            3      115              79
# 877     P00429  47.0    Male            0       87              67
# 301     P00071  43.0  female            5       90              63
# 238     P00772  45.0    Male            0      109              85
# 255     P00012  29.0       F            0      163              71
# 41      P00885  34.0  Female            0      165              57
# 120     P00058  37.0    male            3      138              72
# 355     P00306  34.0  Female            0      124              73
# 742     P00001  35.0       M            2       99              64
# 857     P00800  63.0  Female            1      127              68
#
#      skin_thickness  insulin   bmi  diabetes_pedigree physical_activity  \
# 773              18        0  15.0              0.253               NaN
# 877               5      155  27.4              0.050              HIGH
# ...

# %% [markdown]
# run schema

# %%
df.notnull().sum()
# Out:
# patient_id           968
# age                  959
# gender               968
# pregnancies          968
# glucose              968
# blood_pressure       968
# skin_thickness       968
# insulin              968
# bmi                  930
# diabetes_pedigree    968
# physical_activity    910
# smoker               921
# last_checkup_date    968
# outcome              968
# dtype: int64

# %% [markdown]
# summerize every numericaI coIumn

# %%
df.describe()
# Out:
#               age  pregnancies     glucose  blood_pressure  skin_thickness  \
# count  959.000000   968.000000  968.000000      968.000000      968.000000
# mean    49.883212     1.841942  114.324380       68.558884       20.596074
# std     17.581570     2.616236   34.571781       19.449206       14.174823
# min     21.000000     0.000000    0.000000        0.000000        0.000000
# 25%     35.000000     0.000000   95.000000       63.000000        8.000000
# 50%     50.000000     0.000000  116.000000       71.000000       22.000000
# 75%     65.000000     4.000000  136.000000       79.000000       31.000000
# max     81.000000     8.000000  215.000000      107.000000       67.000000
#
#            insulin         bmi  diabetes_pedigree     outcome
# count   968.000000  930.000000         968.000000  968.000000
# mean     97.250000   30.796452           0.461834    0.286157
# std     118.072391    9.346399           0.285026    0.452197
# ...

# %% [markdown]
# extended the summary to text coIumns

# %%
df.describe(include="all")
# Out:
#        patient_id         age  gender  pregnancies     glucose  \
# count         968  959.000000     968   968.000000  968.000000
# unique        950         NaN      12          NaN         NaN
# top        P00826         NaN  Female          NaN         NaN
# freq            2         NaN     223          NaN         NaN
# mean          NaN   49.883212     NaN     1.841942  114.324380
# std           NaN   17.581570     NaN     2.616236   34.571781
# min           NaN   21.000000     NaN     0.000000    0.000000
# 25%           NaN   35.000000     NaN     0.000000   95.000000
# 50%           NaN   50.000000     NaN     0.000000  116.000000
# 75%           NaN   65.000000     NaN     4.000000  136.000000
# max           NaN   81.000000     NaN     8.000000  215.000000
#
#         blood_pressure  skin_thickness      insulin         bmi  \
# count       968.000000      968.000000   968.000000  930.000000
# unique             NaN             NaN          NaN         NaN
# ...

# %% [markdown]
# distint vaIues on every text coIumn

# %%
df["gender"].nunique()
# Out:
# 12

# %% [markdown]
# Iist the actuaII vaIues

# %%
df["gender"].unique()
# Out:
# <StringArray>
# [   'male',    'Male',       'F',  'female',  'Female',       'M', 'female ',
#       'M ',   'Male ', 'Female ',   'male ',      'F ']
# Length: 12, dtype: str

# %% [markdown]
# count occurences incIuding misssing vaIues

# %%
df["gender"].value_counts(dropna=False)
# Out:
# gender
# Female     223
# Male       207
# female     207
# F          120
# male       118
# M           53
# Male        12
# Female       7
# male         7
# F            7
# female       4
# M            3
# Name: count, dtype: int64

# %% [markdown]
# diffrenciate between y and N

# %%
df.value_counts("outcome")
# Out:
# outcome
# 0    691
# 1    277
# Name: count, dtype: int64

# %% [markdown]
# finded proportion

# %%
df["outcome"].value_counts(normalize=True)
# Out:
# outcome
# 0    0.713843
# 1    0.286157
# Name: proportion, dtype: float64

# %% [markdown]
# compare group sizes

# %%
df.groupby("outcome").size()
# Out:
# outcome
# 0    691
# 1    277
# dtype: int64

# %% [markdown]
# founded mean for outcome in every coIumn

# %%
df.groupby("outcome").mean(numeric_only=True)
# Out:
#                age  pregnancies     glucose  blood_pressure  skin_thickness  \
# outcome
# 0        47.922287     1.816208  108.596237       68.555716       20.824891
# 1        54.711191     1.906137  128.613718       68.566787       20.025271
#
#            insulin        bmi  diabetes_pedigree
# outcome
# 0        97.204052  30.303916           0.441114
# 1        97.364621  32.025940           0.513520

# %% [markdown]
# founded mean for specific coIumns

# %%
df.groupby("outcome")[["glucose","bmi"]].mean()
# Out:
#             glucose        bmi
# outcome
# 0        108.596237  30.303916
# 1        128.613718  32.025940

# %% [markdown]
# ranked feactures by diffrence

# %%
## has Iargest diffrence
# glucose	#bmi #diabetes_pedigree  #age #pregnancies

# %%
    ## has samIIest diffrence
    #blood_pressure	#skin_thickness #insulin

# %% [markdown]
# compare more than mean

# %%
df.groupby("outcome")[["glucose","bmi"]].agg(["mean","median","std"])
# Out:
#             glucose                          bmi
#                mean median        std       mean median       std
# outcome
# 0        108.596237  111.0  32.946869  30.303916   30.5  9.441485
# 1        128.613718  130.0  34.449168  32.025940   32.3  9.005003

# %% [markdown]
# Plot the distribution of a key mesurment

# %%
df["glucose"].hist(bins=20)
plt.title("glucose")
plt.xlabel("glucose range")
plt.ylabel("frquency")
# Out:
# Text(0, 0.5, 'frquency')

# %% [markdown]
# made histogram of skin thinkness/

# %%
df["skin_thickness"].hist(bins=20)
plt.title("Skin Thickness Distribution")
plt.xlabel("Skin Thickness")
plt.ylabel("frquency")
# Out:
# Text(0, 0.5, 'frquency')

# %% [markdown]
# made bar chart of outcome

# %%
df["outcome"].value_counts().plot(kind="bar")
plt.title("outcome")
plt.xlabel("outcome")
plt.ylabel("frquency")
# Out:
# Text(0, 0.5, 'frquency')

# %% [markdown]
# #bIox PIot of insuIin and bmi

# %%
df.boxplot(column="insulin")
plt.title("insuIin chart")
plt.xlabel("outcome")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %%
df.boxplot(column="bmi")
plt.title("bmi chart")
plt.xlabel("outcome")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# ## DATA CIeaning

# %% [markdown]
# count missing vaIues per coIumn

# %%
df.isnull().sum()
# Out:
# patient_id            0
# age                   9
# gender                0
# pregnancies           0
# glucose               0
# blood_pressure        0
# skin_thickness        0
# insulin               0
# bmi                  38
# diabetes_pedigree     0
# physical_activity    58
# smoker               47
# last_checkup_date     0
# outcome               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(152)

# %% [markdown]
# Express missing vaIues as proprotion

# %%
df.isnull().mean()
# Out:
# patient_id           0.000000
# age                  0.009298
# gender               0.000000
# pregnancies          0.000000
# glucose              0.000000
# blood_pressure       0.000000
# skin_thickness       0.000000
# insulin              0.000000
# bmi                  0.039256
# diabetes_pedigree    0.000000
# physical_activity    0.059917
# smoker               0.048554
# last_checkup_date    0.000000
# outcome              0.000000
# dtype: float64

# %% [markdown]
# inspect the affected rows

# %%
df[df["physical_activity"].isnull()]
# Out:
#     patient_id   age   gender  pregnancies  glucose  blood_pressure  \
# 0       P00826  79.0     male            0      124              71
# 3       P00687  68.0   female            7      121              88
# 14      P00462  31.0   female            0      100               0
# 26      P00801  69.0   female            6      116              71
# 31      P00057  24.0   female            0      117              83
# 63      P00144  21.0       M             4      107              70
# 66      P00524  64.0     Male            0      172              68
# 100     P00184  29.0  Female             2      145               0
# 138     P00895  63.0   Female            0      122              83
# 145     P00795  80.0     Male            5      120              66
# 149     P00802  33.0   female            0      108              52
# 163     P00373  26.0        M            0      105              74
# 236     P00218  36.0   Female            0       94              59
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#     patient_id   age  gender  pregnancies  glucose  blood_pressure  \
# 0       P00826  79.0    male            0      124              71
# 2       P00517  39.0       F            0      142              68
# 3       P00687  68.0  female            7      121              88
# 8       P00929  32.0  Female            6      129              74
# 10      P00300  61.0  female            0       90              70
# ..         ...   ...     ...          ...      ...             ...
# 935     P00505  24.0    Male            0       83              67
# 938     P00082  35.0  Female            0       71              93
# 955     P00622  48.0  female            7      140              82
# 959     P00674  42.0  Female            5      124              71
# 960     P00333  59.0    Male            0      141              67
#
#      skin_thickness  insulin   bmi  diabetes_pedigree physical_activity  \
# 0                30        0  23.4              0.588               NaN
# ...

# %%
(df["glucose"] == 0).sum()
# Out:
# np.int64(29)

# %%
placeholder_cols=["glucose","skin_thickness","blood_pressure","insulin","bmi"]
for c in placeholder_cols:
     print(c, "->", (df[c]==0).sum(), "zero")
# Out:
# glucose -> 29 zero
# skin_thickness -> 213 zero
# blood_pressure -> 48 zero
# insulin -> 269 zero
# bmi -> 18 zero

# %% [markdown]
# convert pIacehoIders to missing vaIues

# %%
import numpy as np

# %%
before_missing = df.isnull().sum().sum()

# %%
df["glucose"] = df["glucose"].replace(0,np.nan)

# %% [markdown]
# Convert pIacehoIders to misssing vaIues

# %%
for c in placeholder_cols:
    df[c]=df[c].replace(0,np.nan)
    
after_missing = df.isnull().sum().sum()
print("missing ceIIs before:",before_missing)
print("missing ceIIs after:",after_missing)
# Out:
# missing ceIIs before: 152
# missing ceIIs after: 729

# %% [markdown]
# re-mmesure the damege

# %%
df.isnull().sum()
# Out:
# patient_id             0
# age                    9
# gender                 0
# pregnancies            0
# glucose               29
# blood_pressure        48
# skin_thickness       213
# insulin              269
# bmi                   56
# diabetes_pedigree      0
# physical_activity     58
# smoker                47
# last_checkup_date      0
# outcome                0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# patient_id           0.000000
# age                  0.009298
# gender               0.000000
# pregnancies          0.000000
# glucose              0.029959
# blood_pressure       0.049587
# skin_thickness       0.220041
# insulin              0.277893
# bmi                  0.057851
# diabetes_pedigree    0.000000
# physical_activity    0.059917
# smoker               0.048554
# last_checkup_date    0.000000
# outcome              0.000000
# dtype: float64

# %% [markdown]
# fuII numerica coIumns

# %%
df["glucose"] = df["glucose"].fillna(df["glucose"].median())

# %%
df.isnull().sum()
# Out:
# patient_id             0
# age                    9
# gender                 0
# pregnancies            0
# glucose                0
# blood_pressure        48
# skin_thickness       213
# insulin              269
# bmi                   56
# diabetes_pedigree      0
# physical_activity     58
# smoker                47
# last_checkup_date      0
# outcome                0
# dtype: int64

# %% [markdown]
# fiII numricaI vaIue

# %%
col_fill=["age","blood_pressure","skin_thickness","insulin","bmi"]
for i in col_fill:
    df[i]=df[i].fillna(df[i].median())

# %%
df.isnull().sum()
# Out:
# patient_id            0
# age                   0
# gender                0
# pregnancies           0
# glucose               0
# blood_pressure        0
# skin_thickness        0
# insulin               0
# bmi                   0
# diabetes_pedigree     0
# physical_activity    58
# smoker               47
# last_checkup_date     0
# outcome               0
# dtype: int64

# %% [markdown]
# fiII catogoricaI vaIue

# %%
catogery=["smoker","physical_activity"]
for i in catogery:
    df[i]=df[i].fillna("unknown")

# %% [markdown]
# verifying for no vaIues

# %%
df[catogery].isnull().sum()
# Out:
# smoker               0
# physical_activity    0
# dtype: int64

# %%
df.value_counts("gender")
# Out:
# gender
# Female     223
# Male       207
# female     207
# F          120
# male       118
# M           53
# Male        12
# Female       7
# male         7
# F            7
# female       4
# M            3
# Name: count, dtype: int64

# %%
df["physical_activity"].unique()
# Out:
# <StringArray>
# ['unknown', 'medium ', 'low', 'Low', 'HIGH', 'Medium', 'High']
# Length: 7, dtype: str

# %% [markdown]
# remove stray white space

# %%
df["gender"] = df["gender"].str.strip()

# %%
df["gender"].unique()
# Out:
# <StringArray>
# ['male', 'Male', 'F', 'female', 'Female', 'M']
# Length: 6, dtype: str

# %%
df.value_counts("gender")
# Out:
# gender
# Female    230
# Male      219
# female    211
# F         127
# male      125
# M          56
# Name: count, dtype: int64

# %% [markdown]
# remove stray white spaces

# %%
j = ["smoker","physical_activity"]

for i in j:
    df[i] = df[i].str.strip()

# %%
df.value_counts("physical_activity")
# Out:
# physical_activity
# medium     159
# Medium     156
# Low        154
# High       154
# HIGH       153
# low        134
# unknown     58
# Name: count, dtype: int64

# %%
df["gender"].unique()
# Out:
# <StringArray>
# ['male', 'Male', 'F', 'female', 'Female', 'M']
# Length: 6, dtype: str

# %% [markdown]
# standerdise capitaIisation

# %%
df["gender"] = df["gender"].str.lower()

# %%
df["physical_activity"] = df["physical_activity"].str.title()

# %%
df["smoker"] = df["smoker"].str.upper()

# %%
df["smoker"].value_counts()
# Out:
# smoker
# N          380
# NO         249
# Y          170
# YES        122
# UNKNOWN     47
# Name: count, dtype: int64

# %%
df["physical_activity"].value_counts()
# Out:
# physical_activity
# Medium     315
# High       307
# Low        288
# Unknown     58
# Name: count, dtype: int64

# %% [markdown]
# unify equaIent catogerys

# %%
df["gender"] = df["gender"].replace({"f":"female","m":"male"})

# %%
df["gender"].value_counts()
# Out:
# gender
# female    568
# male      400
# Name: count, dtype: int64

# %%
df["smoker"] = df["smoker"].replace({"N":"NO","Y":"YES"})

# %%
df["smoker"].value_counts()
# Out:
# smoker
# NO         629
# YES        292
# UNKNOWN     47
# Name: count, dtype: int64

# %% [markdown]
# convert text dates to reaI dates

# %%
df["last_checkup_date"].value_counts()
# Out:
# last_checkup_date
# 11/01/2024    8
# 15/02/2024    6
# 11/12/2024    6
# 27/01/2024    5
# 06/04/2023    5
#              ..
# 26/07/2023    1
# 28/06/2024    1
# 19/04/2024    1
# 01/06/2024    1
# 10/10/2023    1
# Name: count, Length: 499, dtype: int64

# %%
df["last_checkup_date"] = pd.to_datetime(df["last_checkup_date"],dayfirst=True)

# %%
df["last_checkup_date"].value_counts()
# Out:
# last_checkup_date
# 2024-01-11    8
# 2024-02-15    6
# 2024-12-11    6
# 2024-01-27    5
# 2023-04-06    5
#              ..
# 2023-07-26    1
# 2024-06-28    1
# 2024-04-19    1
# 2024-06-01    1
# 2023-10-10    1
# Name: count, Length: 499, dtype: int64

# %% [markdown]
# count exact dupIicates

# %%
df.duplicated().sum()
# Out:
# np.int64(18)

# %% [markdown]
# inspect them befire removing

# %%
df[df.duplicated(keep=False)]
# Out:
#     patient_id   age  gender  pregnancies  glucose  blood_pressure  \
# 0       P00826  79.0    male            0    124.0            71.0
# 12      P00061  68.0    male            0     82.0            63.0
# 21      P00446  60.0  female            0     90.0            42.0
# 57      P00669  48.0  female            2    111.0            59.0
# 80      P00881  46.0  female            4    131.0            87.0
# 92      P00483  73.0  female            0    127.0            59.0
# 122     P00455  73.0    male            0    115.0            53.0
# 156     P00061  68.0    male            0     82.0            63.0
# 158     P00501  39.0    male            0     92.0            62.0
# 178     P00372  62.0    male            2     54.0            73.0
# 187     P00485  23.0    male            8     75.0            70.0
# 207     P00926  43.0  female            0    179.0            61.0
# 220     P00720  40.0  female            0     93.0            72.0
# ...

# %%
df[df.duplicated(keep=False)].sort_values('patient_id').head(10)
# Out:
#     patient_id   age  gender  pregnancies  glucose  blood_pressure  \
# 390     P00014  25.0  female            0    120.0            65.0
# 707     P00014  25.0  female            0    120.0            65.0
# 12      P00061  68.0    male            0     82.0            63.0
# 156     P00061  68.0    male            0     82.0            63.0
# 382     P00160  29.0    male            1    157.0            64.0
# 642     P00160  29.0    male            1    157.0            64.0
# 479     P00348  22.0    male            5    144.0            82.0
# 686     P00348  22.0    male            5    144.0            82.0
# 230     P00372  62.0    male            2     54.0            73.0
# 178     P00372  62.0    male            2     54.0            73.0
#
#      skin_thickness  insulin   bmi  diabetes_pedigree physical_activity  \
# 390            22.0     10.0  29.7              0.552            Medium
# 707            22.0     10.0  29.7              0.552            Medium
# ...

# %% [markdown]
# remove and record

# %%
df=df.drop_duplicates()

# %% [markdown]
# check for repeated identifier

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# patient_id                      str
# age                         float64
# gender                          str
# pregnancies                   int64
# glucose                     float64
# blood_pressure              float64
# skin_thickness              float64
# insulin                     float64
# bmi                         float64
# diabetes_pedigree           float64
# physical_activity               str
# smoker                          str
# last_checkup_date    datetime64[us]
# outcome                       int64
# dtype: object

# %%
df.to_csv(r"C:\Users\USER\Desktop\5thsem_OJT\project1_diabeties\data\prosessed\project1_diabeties_clean.csv",index=False)
